# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.8/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/drive/MyDrive/Myntra_Classifier
# Out:
# /content/drive/MyDrive/Myntra_Classifier

# %%
# !ls
# Out:
# classes.txt  config.yaml  data.yaml  test  train  train_model.ipynb  val

# %%
# !yolo task=detect mode=train model=yolov8l.pt data=config.yaml epochs=15 imgsz=210 save=True
# Out:
# ...
# 100% 83.7M/83.7M [00:00<00:00, 146MB/s]
# New https://pypi.org/project/ultralytics/8.2.16 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image(filename="/content/drive/MyDrive/Myntra_Classifier/runs/detect/train/val_batch0_labels.jpg",width=600)

# %% [markdown]
# #Pridiction

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/Myntra_Classifier/runs/detect/train/weights/best.pt show=True conf = 0.25 source="/content/drive/MyDrive/Myntra_Classifier/test/images" imgsz=180 save_txt = True
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 43608150 parameters, 0 gradients, 164.8 GFLOPs
#
# WARNING ⚠️ imgsz=[180] must be multiple of max stride 32, updating to [192]
# image 1/2 /content/drive/MyDrive/Myntra_Classifier/test/images/image_524.jpg: 192x160 2 Males, 84.8ms
# image 2/2 /content/drive/MyDrive/Myntra_Classifier/test/images/image_9.jpg: 192x160 1 Female, 17.6ms
# Speed: 0.9ms preprocess, 51.2ms inference, 279.3ms postprocess per image at shape (1, 3, 192, 160)
# Results saved to runs/detect/predict
# 2 labels saved to runs/detect/predict/labels
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/Myntra_Classifier/runs/detect/train/weights/best.pt show=True conf = 0.25 source="/content/drive/MyDrive/Myntra_Classifier/test/Test.mp4" save_txt = True
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 43608150 parameters, 0 gradients, 164.8 GFLOPs
#
# WARNING ⚠️ NMS time limit 0.550s exceeded
# video 1/1 (1/300) /content/drive/MyDrive/Myntra_Classifier/test/Test.mp4: 128x224 1 Male, 3 Females, 192.4ms
# video 1/1 (2/300) /content/drive/MyDrive/Myntra_Classifier/test/Test.mp4: 128x224 1 Male, 3 Females, 17.8ms
# video 1/1 (3/300) /content/drive/MyDrive/Myntra_Classifier/test/Test.mp4: 128x224 1 Male, 3 Females, 17.2ms
# video 1/1 (4/300) /content/drive/MyDrive/Myntra_Classifier/test/Test.mp4: 128x224 1 Male, 3 Females, 20.1ms
# video 1/1 (5/300) /content/drive/MyDrive/Myntra_Classifier/test/Test.mp4: 128x224 1 Male, 3 Females, 17.7ms
# video 1/1 (6/300) /content/drive/MyDrive/Myntra_Classifier/test/Test.mp4: 128x224 1 Male, 3 Females, 17.5ms
# ...
